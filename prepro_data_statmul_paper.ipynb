# %%
import pandas as pd
from functools import reduce

# %% [markdown]
# # **variabel 1: AHH**

# %%
url1 = 'https://raw.githubusercontent.com/naiarch/faktor-analisis-dan-clustering-data-bps/main/Angka%20Harapan%20Hidup%20(AHH)%20Menurut%20Provinsi%20dan%20Jenis%20Kelamin%2C%202024.csv'
df1 = pd.read_csv(url1, skiprows=3, skipfooter=2, names=['Provinsi', 'Laki-laki', 'Perempuan'], engine='python')
df1
# Out:
#                 Provinsi  Laki-laki  Perempuan
# 0                   ACEH      68.52      72.45
# 1         SUMATERA UTARA      68.36      72.30
# 2         SUMATERA BARAT      68.41      72.35
# 3                   RIAU      70.56      74.58
# 4                  JAMBI      70.09      74.09
# 5       SUMATERA SELATAN      69.00      72.95
# 6               BENGKULU      68.21      72.15
# 7                LAMPUNG      69.56      73.54
# 8   KEP. BANGKA BELITUNG      69.55      73.52
# 9              KEP. RIAU      69.30      73.27
# 10           DKI JAKARTA      72.08      76.28
# 11            JAWA BARAT      72.26      76.56
# 12           JAWA TENGAH      73.21      76.99
# 13         DI YOGYAKARTA      73.66      77.40
# 14            JAWA TIMUR      70.39      74.40
# 15                BANTEN      69.09      73.04
# 16                  BALI      71.19      75.49
# 17   NUSA TENGGARA BARAT      65.79      69.77
# 18   NUSA TENGGARA TIMUR      66.04      70.03
# ...

# %%
df1['AHH'] = (df1['Laki-laki'] + df1['Perempuan']) / 2

df1 = df1.drop(columns=['Laki-laki', 'Perempuan'])
df1 = df1.iloc[:38]
df1
# Out:
#                 Provinsi     AHH
# 0                   ACEH  70.485
# 1         SUMATERA UTARA  70.330
# 2         SUMATERA BARAT  70.380
# 3                   RIAU  72.570
# 4                  JAMBI  72.090
# 5       SUMATERA SELATAN  70.975
# 6               BENGKULU  70.180
# 7                LAMPUNG  71.550
# 8   KEP. BANGKA BELITUNG  71.535
# 9              KEP. RIAU  71.285
# 10           DKI JAKARTA  74.180
# 11            JAWA BARAT  74.410
# 12           JAWA TENGAH  75.100
# 13         DI YOGYAKARTA  75.530
# 14            JAWA TIMUR  72.395
# 15                BANTEN  71.065
# 16                  BALI  73.340
# 17   NUSA TENGGARA BARAT  67.780
# 18   NUSA TENGGARA TIMUR  68.035
# 19      KALIMANTAN BARAT  71.600
# 20     KALIMANTAN TENGAH  70.475
# 21    KALIMANTAN SELATAN  69.695
# 22      KALIMANTAN TIMUR  75.055
# 23      KALIMANTAN UTARA  72.775
# 24        SULAWESI UTARA  72.745
# 25       SULAWESI TENGAH  69.465
# 26      SULAWESI SELATAN  71.480
# ...

# %% [markdown]
# # **variabel 2: sarana kesehatan**

# %%
url2 = 'https://raw.githubusercontent.com/naiarch/faktor-analisis-dan-clustering-data-bps/main/Jumlah%20Desa_Kelurahan%20Yang%20Memiliki%20Sarana%20Kesehatan%20Menurut%20Provinsi%2C%202024.csv'
df2 = pd.read_csv(url2)
df2
# Out:
#                                              Provinsi  \
# 0                                                Aceh
# 1                                      Sumatera Utara
# 2                                      Sumatera Barat
# 3                                                Riau
# 4                                               Jambi
# 5                                    Sumatera Selatan
# 6                                            Bengkulu
# 7                                             Lampung
# 8                           Kepulauan Bangka Belitung
# 9                                      Kepulauan Riau
# 10                                        DKI Jakarta
# 11                                         Jawa Barat
# 12                                        Jawa Tengah
# 13                                      DI Yogyakarta
# 14                                         Jawa Timur
# 15                                             Banten
# ...

# %%
df2 = df2[[
    'Provinsi',
    'Desa/Kelurahan Yang Memiliki Sarana Kesehatan - Rumah Sakit',
    'Desa/Kelurahan Yang Memiliki Sarana Kesehatan - Puskesmas'
]]

df2 = df2.iloc[:38]

df2
# Out:
#                      Provinsi  \
# 0                        Aceh
# 1              Sumatera Utara
# 2              Sumatera Barat
# 3                        Riau
# 4                       Jambi
# 5            Sumatera Selatan
# 6                    Bengkulu
# 7                     Lampung
# 8   Kepulauan Bangka Belitung
# 9              Kepulauan Riau
# 10                DKI Jakarta
# 11                 Jawa Barat
# 12                Jawa Tengah
# 13              DI Yogyakarta
# 14                 Jawa Timur
# 15                     Banten
# 16                       Bali
# 17        Nusa Tenggara Barat
# 18        Nusa Tenggara Timur
# 19           Kalimantan Barat
# 20          Kalimantan Tengah
# 21         Kalimantan Selatan
# 22           Kalimantan Timur
# 23           Kalimantan Utara
# 24             Sulawesi Utara
# 25            Sulawesi Tengah
# 26           Sulawesi Selatan
# 27          Sulawesi Tenggara
# 28                  Gorontalo
# 29             Sulawesi Barat
# ...

# %% [markdown]
# # **variabel 3: Persentase Penduduk Miskin**

# %%
url3 = 'https://raw.githubusercontent.com/naiarch/faktor-analisis-dan-clustering-data-bps/main/Jumlah%20dan%20Persentase%20Penduduk%20Miskin%20Menurut%20Provinsi%2C%202024.csv'
df3 = pd.read_csv(url3)
df3
# Out:
#                      Provinsi  Garis Kemiskinan - Maret (Rp)  \
# 0                        Aceh                         661227
# 1              Sumatera Utara                         642423
# 2              Sumatera Barat                         708416
# 3                        Riau                         697296
# 4                       Jambi                         650115
# 5            Sumatera Selatan                         554197
# 6                    Bengkulu                         671095
# 7                     Lampung                         586551
# 8   Kepulauan Bangka Belitung                         908397
# 9              Kepulauan Riau                         787211
# 10                DKI Jakarta                         825288
# 11                 Jawa Barat                         524052
# 12                Jawa Tengah                         507001
# 13              DI Yogyakarta                         602437
# ...

# %%
df3 = df3[['Provinsi','Persentase Penduduk Miskin - September']]
df3.columns = [
    'Provinsi',
    'Persentase_Penduduk_Miskin'
]
df3 = df3.iloc[:38]
df3
# Out:
#                      Provinsi  Persentase_Penduduk_Miskin
# 0                        Aceh                       12.64
# 1              Sumatera Utara                        7.19
# 2              Sumatera Barat                        5.42
# 3                        Riau                        6.36
# 4                       Jambi                        7.26
# 5            Sumatera Selatan                       10.51
# 6                    Bengkulu                       12.52
# 7                     Lampung                       10.62
# 8   Kepulauan Bangka Belitung                        5.08
# 9              Kepulauan Riau                        4.78
# 10                DKI Jakarta                        4.14
# 11                 Jawa Barat                        7.08
# 12                Jawa Tengah                        9.58
# 13              DI Yogyakarta                       10.40
# 14                 Jawa Timur                        9.56
# ...

# %% [markdown]
# # **variabel 4: Kepadatan Penduduk**

# %%
url4 = 'https://raw.githubusercontent.com/naiarch/faktor-analisis-dan-clustering-data-bps/main/Penduduk%2C%20Laju%20Pertumbuhan%20Penduduk%2C%20Distribusi%20Persentase%20Penduduk%2C%20Kepadatan%20Penduduk%2C%20Rasio%20Jenis%20Kelamin%20Penduduk%20Menurut%20Provinsi%2C%202024.csv'
df4 = pd.read_csv(url4)
df4
# Out:
#                                              Provinsi  Jumlah Penduduk (Ribu)  \
# 0                                                Aceh                  5554.8
# 1                                      Sumatera Utara                 15588.5
# 2                                      Sumatera Barat                  5836.2
# 3                                                Riau                  6728.1
# 4                                               Jambi                  3724.3
# 5                                    Sumatera Selatan                  8837.3
# 6                                            Bengkulu                  2112.2
# 7                                             Lampung                  9419.6
# 8                           Kepulauan Bangka Belitung                  1531.5
# 9                                      Kepulauan Riau                  2183.3
# 10                                        DKI Jakarta                 10684.9
# ...

# %%
df4 = df4[['Provinsi','Kepadatan Penduduk per km persegi (Km2)']]
df4.columns = [
    'Provinsi',
    'Kepadatan_Penduduk'
]

df4 = df4.iloc[:38]
df4
# Out:
#                      Provinsi  Kepadatan_Penduduk
# 0                        Aceh                98.0
# 1              Sumatera Utara               215.0
# 2              Sumatera Barat               139.0
# 3                        Riau                75.0
# 4                       Jambi                76.0
# 5            Sumatera Selatan               102.0
# 6                    Bengkulu               105.0
# 7                     Lampung               281.0
# 8   Kepulauan Bangka Belitung                92.0
# 9              Kepulauan Riau               264.0
# 10                DKI Jakarta             16165.0
# 11                 Jawa Barat              1359.0
# 12                Jawa Tengah              1104.0
# 13              DI Yogyakarta              1186.0
# 14                 Jawa Timur               870.0
# 15                     Banten              1329.0
# 16                       Bali               793.0
# 17        Nusa Tenggara Barat               287.0
# ...

# %% [markdown]
# # **variabel 5: Persentase Keluhan Kesehatan**

# %%
url5 = 'https://raw.githubusercontent.com/naiarch/faktor-analisis-dan-clustering-data-bps/main/Persentase%20Penduduk%20yang%20Mempunyai%20Keluhan%20Kesehatan%20dalam%20Sebulan%20Terakhir%20Menurut%20Provinsi%2C%202024.csv'
df5 = pd.read_csv(url5, skiprows=3, names=['Provinsi', 'Persentase Keluhan Kesehatan'])
df5
# Out:
#                 Provinsi  Persentase Keluhan Kesehatan
# 0                   ACEH                         25.58
# 1         SUMATERA UTARA                         23.99
# 2         SUMATERA BARAT                         30.10
# 3                   RIAU                         23.60
# 4                  JAMBI                         23.73
# 5       SUMATERA SELATAN                         29.89
# 6               BENGKULU                         28.27
# 7                LAMPUNG                         29.54
# 8   KEP. BANGKA BELITUNG                         28.80
# 9              KEP. RIAU                         26.26
# 10           DKI JAKARTA                         24.07
# 11            JAWA BARAT                         28.88
# 12           JAWA TENGAH                         31.86
# 13         DI YOGYAKARTA                         28.82
# 14            JAWA TIMUR                         28.75
# 15                BANTEN                         25.77
# ...

# %%
df5 = df5.iloc[:38]
df5
# Out:
#                 Provinsi  Persentase Keluhan Kesehatan
# 0                   ACEH                         25.58
# 1         SUMATERA UTARA                         23.99
# 2         SUMATERA BARAT                         30.10
# 3                   RIAU                         23.60
# 4                  JAMBI                         23.73
# 5       SUMATERA SELATAN                         29.89
# 6               BENGKULU                         28.27
# 7                LAMPUNG                         29.54
# 8   KEP. BANGKA BELITUNG                         28.80
# 9              KEP. RIAU                         26.26
# 10           DKI JAKARTA                         24.07
# 11            JAWA BARAT                         28.88
# 12           JAWA TENGAH                         31.86
# 13         DI YOGYAKARTA                         28.82
# 14            JAWA TIMUR                         28.75
# 15                BANTEN                         25.77
# ...

# %% [markdown]
# # **variabel 6: RLS**

# %%
url6 = 'https://raw.githubusercontent.com/naiarch/faktor-analisis-dan-clustering-data-bps/main/Rata-Rata%20Lama%20Sekolah%20Penduduk%20Umur%2015%20Tahun%20ke%20Atas%20Menurut%20Provinsi%2C%202024.csv'
df6 = pd.read_csv(url6, skiprows=3, names=['Provinsi', 'Rata-Rata Lama Sekolah'])
df6
# Out:
#                 Provinsi  Rata-Rata Lama Sekolah
# 0                   ACEH                    9.95
# 1         SUMATERA UTARA                   10.18
# 2         SUMATERA BARAT                    9.72
# 3                   RIAU                    9.69
# 4                  JAMBI                    9.26
# 5       SUMATERA SELATAN                    8.98
# 6               BENGKULU                    9.40
# 7                LAMPUNG                    8.80
# 8   KEP. BANGKA BELITUNG                    8.78
# 9              KEP. RIAU                   10.65
# 10           DKI JAKARTA                   11.49
# 11            JAWA BARAT                    9.24
# 12           JAWA TENGAH                    8.47
# 13         DI YOGYAKARTA                   10.23
# 14            JAWA TIMUR                    8.69
# 15                BANTEN                    9.55
# 16                  BALI                    9.87
# 17   NUSA TENGGARA BARAT                    8.50
# ...

# %%
df6.columns = [
    'Provinsi',
    'RLS'
]

df6 = df6.iloc[:38]
df6
# Out:
#                 Provinsi    RLS
# 0                   ACEH   9.95
# 1         SUMATERA UTARA  10.18
# 2         SUMATERA BARAT   9.72
# 3                   RIAU   9.69
# 4                  JAMBI   9.26
# 5       SUMATERA SELATAN   8.98
# 6               BENGKULU   9.40
# 7                LAMPUNG   8.80
# 8   KEP. BANGKA BELITUNG   8.78
# 9              KEP. RIAU  10.65
# 10           DKI JAKARTA  11.49
# 11            JAWA BARAT   9.24
# 12           JAWA TENGAH   8.47
# 13         DI YOGYAKARTA  10.23
# 14            JAWA TIMUR   8.69
# 15                BANTEN   9.55
# 16                  BALI   9.87
# 17   NUSA TENGGARA BARAT   8.50
# 18   NUSA TENGGARA TIMUR   8.48
# 19      KALIMANTAN BARAT   8.28
# 20     KALIMANTAN TENGAH   9.17
# 21    KALIMANTAN SELATAN   9.02
# 22      KALIMANTAN TIMUR  10.22
# 23      KALIMANTAN UTARA   9.58
# 24        SULAWESI UTARA  10.02
# 25       SULAWESI TENGAH   9.28
# 26      SULAWESI SELATAN   9.22
# 27     SULAWESI TENGGARA   9.74
# ...

# %% [markdown]
# # **variabel 7: TPT**

# %%
url7 = 'https://raw.githubusercontent.com/naiarch/faktor-analisis-dan-clustering-data-bps/main/Tingkat%20Pengangguran%20Terbuka%20Menurut%20Provinsi%20(Persen)%2C%202024.csv'
df7 = pd.read_csv(url7, skiprows=3, skipfooter=2, names=['Provinsi', 'Tingkat Pengangguran Terbuka'], engine='python')
df7
# Out:
#                 Provinsi  Tingkat Pengangguran Terbuka
# 0                   ACEH                          5.75
# 1         SUMATERA UTARA                          5.60
# 2         SUMATERA BARAT                          5.75
# 3                   RIAU                          3.70
# 4                  JAMBI                          4.48
# 5       SUMATERA SELATAN                          3.86
# 6               BENGKULU                          3.11
# 7                LAMPUNG                          4.19
# 8   KEP. BANGKA BELITUNG                          4.63
# 9              KEP. RIAU                          6.39
# 10           DKI JAKARTA                          6.21
# 11            JAWA BARAT                          6.75
# 12           JAWA TENGAH                          4.78
# 13         DI YOGYAKARTA                          3.48
# 14            JAWA TIMUR                          4.19
# 15                BANTEN                          6.68
# ...

# %%
df7.columns = [
    'Provinsi',
    'TPT'
]

df7 = df7.iloc[:38]
df7
# Out:
#                 Provinsi   TPT
# 0                   ACEH  5.75
# 1         SUMATERA UTARA  5.60
# 2         SUMATERA BARAT  5.75
# 3                   RIAU  3.70
# 4                  JAMBI  4.48
# 5       SUMATERA SELATAN  3.86
# 6               BENGKULU  3.11
# 7                LAMPUNG  4.19
# 8   KEP. BANGKA BELITUNG  4.63
# 9              KEP. RIAU  6.39
# 10           DKI JAKARTA  6.21
# 11            JAWA BARAT  6.75
# 12           JAWA TENGAH  4.78
# 13         DI YOGYAKARTA  3.48
# 14            JAWA TIMUR  4.19
# 15                BANTEN  6.68
# 16                  BALI  1.79
# 17   NUSA TENGGARA BARAT  2.73
# 18   NUSA TENGGARA TIMUR  3.02
# 19      KALIMANTAN BARAT  4.86
# 20     KALIMANTAN TENGAH  4.01
# 21    KALIMANTAN SELATAN  4.20
# 22      KALIMANTAN TIMUR  5.14
# 23      KALIMANTAN UTARA  3.90
# 24        SULAWESI UTARA  5.85
# 25       SULAWESI TENGAH  2.94
# 26      SULAWESI SELATAN  4.19
# 27     SULAWESI TENGGARA  3.09
# 28             GORONTALO  3.13
# ...

# %% [markdown]
# # **variabel 8: HLS**

# %%
url8 = 'https://raw.githubusercontent.com/naiarch/faktor-analisis-dan-clustering-data-bps/main/%5BMetode%20Baru%5D%20Harapan%20Lama%20Sekolah%2C%202024.csv'
df8 = pd.read_csv(url8, skiprows=3, names=['Provinsi', 'Harapan Lama Sekolah'])
df8
# Out:
#                Provinsi Harapan Lama Sekolah
# 0                  ACEH                14.39
# 1              Simeulue                14.53
# 2          Aceh Singkil                14.36
# 3          Aceh Selatan                14.71
# 4         Aceh Tenggara                14.47
# ..                  ...                  ...
# 574    Mamberamo Tengah                 9.78
# 575              Yalimo                  9.8
# 576            Yahukimo                 8.05
# 577  Pegunungan Bintang                 7.01
# 578           INDONESIA                13.21
#
# [579 rows x 2 columns]

# %%
provinsi = [
'ACEH','SUMATERA UTARA','SUMATERA BARAT','RIAU','JAMBI',
'SUMATERA SELATAN','BENGKULU','LAMPUNG',
'KEP. BANGKA BELITUNG','KEPULAUAN RIAU','DKI JAKARTA',
'JAWA BARAT','JAWA TENGAH','D I YOGYAKARTA',
'JAWA TIMUR','BANTEN','BALI',
'NUSA TENGGARA BARAT','NUSA TENGGARA TIMUR',
'KALIMANTAN BARAT','KALIMANTAN TENGAH',
'KALIMANTAN SELATAN','KALIMANTAN TIMUR',
'KALIMANTAN UTARA','SULAWESI UTARA',
'SULAWESI TENGAH','SULAWESI SELATAN',
'SULAWESI TENGGARA','GORONTALO',
'SULAWESI BARAT','MALUKU','MALUKU UTARA',
'PAPUA BARAT','PAPUA BARAT DAYA',
'PAPUA','PAPUA SELATAN',
'PAPUA TENGAH','PAPUA PEGUNUNGAN'
]

df8 = df8[df8['Provinsi'].isin(provinsi)]
df8.columns = [
    'Provinsi',
    'HLS'
]

df8 = df8.iloc[:38]
df8 = df8.reset_index(drop=True)

df8
# Out:
#                 Provinsi    HLS
# 0                   ACEH  14.39
# 1         SUMATERA UTARA  13.49
# 2         SUMATERA BARAT   14.3
# 3                   RIAU  13.42
# 4                  JAMBI  13.14
# 5       SUMATERA SELATAN  12.64
# 6               BENGKULU  13.75
# 7                LAMPUNG  12.78
# 8   KEP. BANGKA BELITUNG  12.49
# 9         KEPULAUAN RIAU  13.27
# 10           DKI JAKARTA  13.51
# 11            JAWA BARAT   12.8
# 12           JAWA TENGAH  12.86
# 13        D I YOGYAKARTA   15.7
# 14            JAWA TIMUR  13.43
# 15                BANTEN   13.1
# 16                  BALI  13.62
# 17   NUSA TENGGARA BARAT  13.98
# 18   NUSA TENGGARA TIMUR  13.23
# 19      KALIMANTAN BARAT  12.68
# 20     KALIMANTAN TENGAH  12.77
# 21    KALIMANTAN SELATAN  12.87
# 22      KALIMANTAN TIMUR  14.03
# 23      KALIMANTAN UTARA  13.21
# 24        SULAWESI UTARA  12.97
# 25       SULAWESI TENGAH  13.34
# 26      SULAWESI SELATAN  13.55
# 27     SULAWESI TENGGARA  13.71
# ...

# %%
import pandas as pd

# @title menyamakan nama provinsi

def clean_province(df):

    df['Provinsi'] = (
        df['Provinsi']
        .str.upper()
        .str.strip()
    )

    df['Provinsi'] = df['Provinsi'].replace({
        'KEPULAUAN RIAU':'KEP. RIAU',
        'KEPULAUAN BANGKA BELITUNG':'KEP. BANGKA BELITUNG',
        'D I YOGYAKARTA':'DI YOGYAKARTA'
    })

    return df

# %%
for df in [df1,df2,df3,df4,df5,df6,df7,df8]:
    clean_province(df)
# Out:
# /tmp/ipykernel_63812/1462977985.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Provinsi'] = (
# /tmp/ipykernel_63812/1462977985.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Provinsi'] = df['Provinsi'].replace({

# %% [markdown]
# # **MERGE DATA**

# %%
dfs = [df1,df2,df3,df4,df5,df6,df7,df8]

df_final = reduce(
    lambda left,right:
    pd.merge(
        left,
        right,
        on='Provinsi',
        how='inner'
    ),
    dfs
)

df_final
# Out:
#                 Provinsi     AHH  \
# 0                   ACEH  70.485
# 1         SUMATERA UTARA  70.330
# 2         SUMATERA BARAT  70.380
# 3                   RIAU  72.570
# 4                  JAMBI  72.090
# 5       SUMATERA SELATAN  70.975
# 6               BENGKULU  70.180
# 7                LAMPUNG  71.550
# 8   KEP. BANGKA BELITUNG  71.535
# 9              KEP. RIAU  71.285
# 10           DKI JAKARTA  74.180
# 11            JAWA BARAT  74.410
# 12           JAWA TENGAH  75.100
# 13         DI YOGYAKARTA  75.530
# 14            JAWA TIMUR  72.395
# 15                BANTEN  71.065
# 16                  BALI  73.340
# 17   NUSA TENGGARA BARAT  67.780
# 18   NUSA TENGGARA TIMUR  68.035
# 19      KALIMANTAN BARAT  71.600
# 20     KALIMANTAN TENGAH  70.475
# 21    KALIMANTAN SELATAN  69.695
# 22      KALIMANTAN TIMUR  75.055
# 23      KALIMANTAN UTARA  72.775
# 24        SULAWESI UTARA  72.745
# 25       SULAWESI TENGAH  69.465
# 26      SULAWESI SELATAN  71.480
# ...

# %%
# @title missing value
df_final.isnull().sum()
# Out:
# Provinsi                                                       0
# AHH                                                            0
# Desa/Kelurahan Yang Memiliki Sarana Kesehatan - Rumah Sakit    0
# Desa/Kelurahan Yang Memiliki Sarana Kesehatan - Puskesmas      0
# Persentase_Penduduk_Miskin                                     0
# Kepadatan_Penduduk                                             0
# Persentase Keluhan Kesehatan                                   0
# RLS                                                            0
# TPT                                                            0
# HLS                                                            0
# dtype: int64

# %%
# @title cek duplikasi data

df_final.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # **DATASET FINAL**

# %%
df_final.to_csv(
    'dataset_paper_statmul.csv',
    index=False
)
